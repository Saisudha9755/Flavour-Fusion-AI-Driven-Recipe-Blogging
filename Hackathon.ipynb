# %%
# !pip install transformers

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.2 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login

login(token="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")

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained model and tokenizer
model_name = "gpt2"  # You can change this to any other model on Hugging Face
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Encode input prompt for recipe generation
input_prompt = "Create a recipe for a delicious vegan pasta dish."
inputs = tokenizer.encode(input_prompt, return_tensors="pt")

# Generate the recipe text
output = model.generate(inputs, max_length=150, num_return_sequences=1)

# Decode the output and display
recipe = tokenizer.decode(output[0], skip_special_tokens=True)
print(recipe)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
# Get input from the user
input_prompt = input("Enter your recipe idea: ")

# Encode input prompt and generate recipe
inputs = tokenizer.encode(input_prompt, return_tensors="pt")
output = model.generate(inputs, max_length=150, num_return_sequences=1)
recipe = tokenizer.decode(output[0], skip_special_tokens=True)

# Display generated recipe
print("\nGenerated Recipe:")
print(recipe)
# Out:
# Enter your recipe idea: maggi
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Recipe:
# maggi, who was also a member of the group, said he was "very disappointed" by the decision.
#
# "I think it's a very sad day for the community," he said. "I think it's a very sad day for the community. I think it's a very sad day for the community."
#
# The group's leader, Michael O'Brien, said he was "very disappointed" by the decision.
#
# "I think it's a very sad day for the community," he said. "I think it's a very sad day for the community."
#
# The group's leader, Michael O'Brien, said he was "very disappointed" by the decision. (CBC)
#
# The

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Take user input for the recipe prompt
input_prompt = input("Enter a recipe idea: ")

# Generate and display the recipe
recipe = generate_recipe(input_prompt)
print("\nGenerated Recipe:\n")
print(recipe)
# Out:
# Enter a recipe idea: maggi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bcd9b5f989f4> in <cell line: 0>()
#      30
#      31 # Generate and display the recipe
# ---> 32 recipe = generate_recipe(input_prompt)
#      33 print("\nGenerated Recipe:\n")
#      34 print(recipe)
#
# <ipython-input-7-bcd9b5f989f4> in generate_recipe(prompt)
#      15
#      16     # Create attention mask (1 for real tokens, 0 for padding tokens)
# ---> 17     attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1
#      18
#      19     # Generate a recipe (set max length to control the output length)
#
# NameError: name 'torch' is not defined

# %%
# Import torch
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained GPT-2 model and tokenizer
model_name = "Abdulmannan/recipe_model_llama3"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Take user input for the recipe prompt
input_prompt = input("Enter a recipe idea: ")

# Generate and display the recipe
recipe = generate_recipe(input_prompt)
print("\nGenerated Recipe:\n")
print(recipe)
# Out:
# adapter_config.json:   0%|          | 0.00/732 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# You are using a model of type llama to instantiate a model of type gpt2. This is not supported for all configurations of models and can yield errors.
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/lib/python3.11/importlib/metadata/__init__.py in from_name(cls, name)
#     562         try:
# --> 563             return next(cls.discover(name=name))
#     564         except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# PackageNotFoundError                      Traceback (most recent call last)
# ...

# %%
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Ensure we are using GPT-2
model_name = "gpt2"  # You can also use "gpt2-medium", "gpt2-large", or other variants.
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Take user input for the recipe prompt
input_prompt = input("Enter a recipe idea: ")

# Generate and display the recipe
recipe = generate_recipe(input_prompt)
print("\nGenerated Recipe:\n")
print(recipe)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9cb533262ee2> in <cell line: 0>()
#      28
#      29 # Take user input for the recipe prompt
# ---> 30 input_prompt = input("Enter a recipe idea: ")
#      31
#      32 # Generate and display the recipe
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Directly define the recipe idea
input_prompt = "maggi"

# Generate and display the recipe
recipe = generate_recipe(input_prompt)
print("\nGenera
# Out:
#   File "<ipython-input-16-e7f7961cbca7>", line 34
#     print("\nGenera
#           ^
# SyntaxError: unterminated string literal (detected at line 34)

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import ipywidgets as widgets
from IPython.display import display

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create an input field
input_field = widgets.Text(
    description='Recipe Idea:',
    value='maggi',  # Default input
)

# Display input field
display(input_field)

# Define a function to generate the recipe when the button is pressed
def on_button_click(b):
    recipe = generate_recipe(input_field.value)
    print("\nGenerated Recipe:\n")  # Fixed string issue here
    print(recipe)

# Create a button to trigger the recipe generation
button = widgets.Button(description="Generate Recipe")
button.on_click(on_button_click)

# Display the button
display(button)
# Out:
# Text(value='maggi', description='Recipe Idea:')
# Button(description='Generate Recipe', style=ButtonStyle())
# Generated Recipe:
#
# maggi, who was also a member of the group, said he was "very disappointed" by the decision.
#
# "I think it's a very sad day for the community," he said. "I think it's a very sad day for the community. I think it's a very sad day for the community."
#
# The group's leader, Michael O'Brien, said he was "very disappointed" by the decision.
#
# "I think it's a very sad day for the community," he said. "I think it's a very sad day for the community."
#
# The group's leader, Michael O'Brien, said he was "very disappointed" by the decision. (CBC)
#
# The
#
# Generated Recipe:
#
# maggi, who was also a member of the group, said he was "very disappointed" by the decision.
#
# "I think it's a very sad day for the community," he said. "I think it's a very sad day for the community. I think it's a very sad day for the community."
#
# ...

# %%
# !pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.9/321.9 kB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 91.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import gradio as gr

# Load the pre-trained GPT-2 model and tokenizer
model_name = "import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import gradio as gr

# Load the pre-trained GPT-2 model and tokenizer
model_name = "import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import gradio as gr

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create Gradio interface
def create_interface():
    # Define input and output components for Gradio
    interface = gr.Interface(fn=generate_recipe,
                             inputs=gr.Textbox(label="Enter Recipe Idea", placeholder="e.g., maggi, pasta, pizza"),
                             outputs=gr.Textbox(label="Generated Recipe"),
                             title="AI Recipe Generator",
                             description="Enter a recipe idea to get an AI-generated recipe. Powered by GPT-2.")
    # Launch the web app
    interface.launch()

# Launch the app
create_interface()
"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create Gradio interface
def create_interface():
    # Define input and output components for Gradio
    interface = gr.Interface(fn=generate_recipe,
                             inputs=gr.Textbox(label="Enter Recipe Idea", placeholder="e.g., maggi, pasta, pizza"),
                             outputs=gr.Textbox(label="Generated Recipe"),
                             title="AI Recipe Generator",
                             description="Enter a recipe idea to get an AI-generated recipe. Powered by GPT-2.")
    # Launch the web app
    interface.launch()

# Launch the app
create_interface()
"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create Gradio interface
def create_interface():
    # Define input and output components for Gradio
    interface = gr.Interface(fn=generate_recipe,
                             inputs=gr.Textbox(label="Enter Recipe Idea", placeholder="e.g., maggi, pasta, pizza"),
                             outputs=gr.Textbox(label="Generated Recipe"),
                             title="AI Recipe Generator",
                             description="Enter a recipe idea to get an AI-generated recipe. Powered by GPT-2.")
    # Launch the web app
    interface.launch()

# Launch the app
create_interface()
# Out:
#   File "<ipython-input-1-11d1608a311b>", line 6
#     model_name = "import torch
#                  ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import gradio as gr

# Load the pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create Gradio interface
def create_interface():
    # Define input and output components for Gradio
# Out:
#   File "<ipython-input-2-b488b217842f>", line 32
#     # Define input and output components for Gradio
#                                                    ^
# SyntaxError: incomplete input

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import gradio as gr

# Load the pre-trained GPT-2 model and tokenizer
model_name = "pratultandon/recipe-nlg-gpt2-train11_15"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Define the padding token ID to be the eos_token_id (End Of Sentence)
tokenizer.pad_token = tokenizer.eos_token

# Function to generate recipe based on a prompt
def generate_recipe(prompt):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe (set max length to control the output length)
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe

# Create Gradio interface
def create_interface():
    # Define input and output components for Gradio
    interface = gr.Interface(fn=generate_recipe,
                             inputs=gr.Textbox(label="Enter Recipe Idea", placeholder="e.g., maggi, pasta, pizza"),
                             outputs=gr.Textbox(label="Generated Recipe"),
                             title="AI Recipe Generator",
                             description="Enter a recipe idea to get an AI-generated recipe. Powered by GPT-2.")

    # Launch the web app
    interface.launch()

# Launch the app
create_interface()
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/885 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/510M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/419 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://58383281157261d5bc.gradio.live
#
# ...

# %%
def generate_recipe(Write a recipe for making Maggi noodles."):
    # Tokenize the input prompt
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    # Create attention mask (1 for real tokens, 0 for padding tokens)
    attention_mask = torch.ones(inputs.shape, dtype=torch.long)  # All tokens are real, so set to 1

    # Generate a recipe with controlled randomness
    output = model.generate(inputs, max_length=150, num_return_sequences=1,
                            pad_token_id=tokenizer.pad_token_id,
                            attention_mask=attention_mask,
                            temperature=0.7,  # Control randomness (lower = more predictable)
                            top_p=0.9)  # Control diversity (sampling from the top 90% of next words)

    # Decode the output tokens back to text
    recipe = tokenizer.decode(output[0], skip_special_tokens=True)
    return recipe
# Out:
#   File "<ipython-input-5-b106203f87e1>", line 1
#     def generate_recipe(Write a recipe for making Maggi noodles."):
#                                                                 ^
# SyntaxError: unterminated string literal (detected at line 1)
